# %%
from collections import deque

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]  # Swap
    return arr

# Example queue of patients
patients_queue = deque([4, 2, 5, 1, 3])

# Step 1: Dequeue into list
patients_list = []
while patients_queue:
    patients_list.append(patients_queue.popleft())

# Step 2: Sort using selection sort
sorted_patients = selection_sort(patients_list)

# Step 3: Enqueue back into queue
for p in sorted_patients:
    patients_queue.append(p)

# Step 4: Display result
print("Final sorted patient queue (most critical first):")
while patients_queue:
    print(patients_queue.popleft(), end=" ")
# Out:
# Final sorted patient queue (most critical first):
# 1 2 3 4 5

# %%
from collections import deque

def selection_sort(arr, descending=False):
    n = len(arr)
    for i in range(n):
        idx = i
        for j in range(i+1, n):
            if not descending and arr[j] < arr[idx]:   # Ascending
                idx = j
            elif descending and arr[j] > arr[idx]:     # Descending
                idx = j
        arr[i], arr[idx] = arr[idx], arr[i]
    return arr

# Example stack of roll numbers
scripts_stack = deque([105, 101, 110, 102, 108])

# Step 1: Pop into list
rolls = []
while scripts_stack:
    rolls.append(scripts_stack.pop())

# Step 2: Sort Ascending
asc_sorted = selection_sort(rolls.copy(), descending=False)

# Step 3: Sort Descending
desc_sorted = selection_sort(rolls.copy(), descending=True)

# Step 4: Push into new stacks
asc_stack = deque()
for r in asc_sorted:
    asc_stack.append(r)

desc_stack = deque()
for r in desc_sorted:
    desc_stack.append(r)

# Step 5: Display results
print("Ascending Order (pop stack):")
while asc_stack:
    print(asc_stack.pop(), end=" ")

print("\nDescending Order (pop stack):")
while desc_stack:
    print(desc_stack.pop(), end=" ")
# Out:
# Ascending Order (pop stack):
# 110 108 105 102 101
# Descending Order (pop stack):
# 101 102 105 108 110

# %%
class Queue:
    def __init__(self, capacity=10):
        self.items = []
        self.capacity = capacity

    def enqueue(self, book_id):
        if not self.is_full():
            self.items.append(book_id)

    def dequeue(self):
        if not self.is_empty():
            return self.items.pop(0)

    def peek(self):
        return self.items[0] if not self.is_empty() else None

    def is_empty(self):
        return len(self.items) == 0

    def is_full(self):
        return len(self.items) == self.capacity

    def display(self):
        print("Queue:", self.items)


class Stack:
    def __init__(self, capacity=10):
        self.items = []
        self.capacity = capacity

    def push(self, book_id):
        if not self.is_full():
            self.items.append(book_id)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()

    def peek(self):
        return self.items[-1] if not self.is_empty() else None

    def is_empty(self):
        return len(self.items) == 0

    def is_full(self):
        return len(self.items) == self.capacity

    def display(self):
        print("Stack:", self.items)


def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr


# Example Returned (Queue) and Issued (Stack)
returned_books = Queue()
for book in [45, 12, 78]:
    returned_books.enqueue(book)

issued_books = Stack()
for book in [34, 90, 23]:
    issued_books.push(book)

# Step 1: Show initial state
print("Initial Returned Books:")
returned_books.display()
print("Initial Issued Books:")
issued_books.display()

# Step 2: Extract all books
returned_list = []
while not returned_books.is_empty():
    returned_list.append(returned_books.dequeue())

issued_list = []
while not issued_books.is_empty():
    issued_list.append(issued_books.pop())

# Step 3: Merge
merged = returned_list + issued_list
print("\nMerged List:", merged)

# Step 4: Sort
sorted_books = selection_sort(merged)
print("Sorted List:", sorted_books)

# Step 5: Reinsert
mid = len(sorted_books) // 2
for b in sorted_books[:mid]:
    returned_books.enqueue(b)
for b in sorted_books[mid:]:
    issued_books.push(b)

# Step 6: Show reinserted
print("\nReinserted Returned Books:")
returned_books.display()
print("Reinserted Issued Books:")
issued_books.display()

# Step 7: Display all again
print("\nDequeued Returned Books:")
while not returned_books.is_empty():
    print(returned_books.dequeue(), end=" ")

print("\nPopped Issued Books:")
while not issued_books.is_empty():
    print(issued_books.pop(), end=" ")
# Out:
# Initial Returned Books:
# Queue: [45, 12, 78]
# Initial Issued Books:
# Stack: [34, 90, 23]
#
# Merged List: [45, 12, 78, 23, 90, 34]
# Sorted List: [12, 23, 34, 45, 78, 90]
#
# Reinserted Returned Books:
# Queue: [12, 23, 34]
# Reinserted Issued Books:
# Stack: [45, 78, 90]
#
# Dequeued Returned Books:
# 12 23 34
# Popped Issued Books:
# 90 78 45
